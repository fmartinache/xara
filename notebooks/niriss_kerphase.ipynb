# %% [markdown]
# # NIRISS commissioning kernel-phase data analysis
#
# This notebook walks through the analysis of NIRISS CLEARP kernel-phase data starting from uncal files and finishing with companion detection limits. Installation instructions are given at the top.

# %% [markdown]
# ## Step 1: install and import libraries
#
# Three libraries are required to run this notebook:
# 1. the JWST data reduction pipeline (https://github.com/spacetelescope/jwst),
# 2. a modified version of Frantz Martinache's XARA toolkit (https://github.com/kammerje/xara),
# 3. Jens Kammerer's fouriever toolkit (https://github.com/kammerje/fouriever).
#
# It is recommended to make a new Conda environment for reducing JWST kernel-phase data. The following steps are required to run this notebook:
# 1. make a new Conda environment, activate it, and install the JWST data reduction pipeline
# ```bash
# conda create -n <name> python
# conda activate <name>
# pip install jwst
# ```
# 2. as of 20 Apr. 2022, downgrade asdf to avoid the pipeline from crashing
# ```bash
# conda install asdf=2.8.3
# ```
# 3. clone the modified version of XARA into a directory of your choice and install it
# ```bash
# mkdir <dir>
# cd <dir>
# git clone --branch develop https://github.com/kammerje/xara.git
# cd xara/
# pip install -e .
# ```
# 4. clone fouriever into a directory of your choice
# ```bash
# cd <dir>
# git clone https://github.com/kammerje/fouriever.git
# ```

# %%
from __future__ import division

import astropy.io.fits as pyfits
import matplotlib.pyplot as plt
import numpy as np

import os
import sys

# Set up CRDS environment variables (required for JWST data reduction pipeline)
os.environ['CRDS_PATH'] = 'crds_cache'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

# Import JWST data reduction pipeline
from jwst.pipeline import Detector1Pipeline, Image2Pipeline

# Import kernel-phase pipeline from XARA
from xara.calwebb_kpi3 import KPI3Pipeline

# Import model fitting tools from fouriever
sys.path.append('/Users/jkammerer/Documents/Code/fouriever') # !!! REPLACE THIS WITH '<dir>/fouriever' !!!
from fouriever import klcal, uvfit

# %% [markdown]
# ## Step 2: run JWST stage 1 & 2 and KPI stage 3 pipelines
#
# The ipc, the photom, and the resample step in the JWST stage 1 & 2 pipelines should be skipped for kernel-phase data, similar as for AMI data. The KPI stage 3 pipeline creates diagnostic plots for each pipeline step that are saved in the output directory of the pipeline. The KPI stage 3 pipeline saves the output into KPFITS files whose structure is outlined here: https://docs.google.com/document/d/1iBbcCYiq9J2PpLSr21-xB4AXP8X_6tSszxnHY1VDGXg/edit?usp=sharing.

# %%
# Get the uncal files
idirs = ['kerphase_testdata/NIRISS/J062802.01-663738.0/',
         'kerphase_testdata/NIRISS/TYC-8906-1660-1/',
         'kerphase_testdata/NIRISS/CPD-66-562/',
         'kerphase_testdata/NIRISS/CPD-67-607/']
files = []
for idir in idirs:
    files += sorted([idir+f for f in os.listdir(idir) if f.endswith('_uncal.fits')])

# Run each file through the pipelines
for file in files:
    
    # Stage 1
    #result1 = Detector1Pipeline()
    #result1.save_results = True
    #result1.output_dir = file[:file.rfind('/')+1]
    #result1.ipc.skip = True # skip IPC step
    #result1.run(file)
    
    # Stage 2
    #result2 = Image2Pipeline()
    #result2.save_results = True
    #result2.output_dir = file[:file.rfind('/')+1]
    #result2.photom.skip = True # skip photom step
    #result2.resample.skip = True # skip resample step
    #result2.run(file.replace('uncal', 'rateints'))
    
    # Stage 3
    result3 = KPI3Pipeline()
    result3.output_dir = None # output directory; if 'None', uses same directory as input data
    # Bad pixel fixing step
    result3.fix_bad_pixels.skip = False # skip step?
    result3.fix_bad_pixels.plot = True # make and save plots?
    result3.fix_bad_pixels.bad_bits = ['SATURATED', 'JUMP_DET'] # DQ flags to be considered as bad pixels (see https://jwst-reffiles.stsci.edu/source/data_quality.html)
    result3.fix_bad_pixels.method = 'medfilt' # method to fix bad pixels; 'medfilt' or 'KI'
    # Re-centering step
    result3.recenter_frames.skip = False # skip step?
    result3.recenter_frames.plot = True # make and save plots?
    result3.recenter_frames.method = 'FPNM' # XARA re-centering method; 'BCEN', 'COGI', or 'FPNM'
    result3.recenter_frames.bmax = 6. # m; maximum baseline length for FPNM re-centering method
    # Windowing step
    result3.window_frames.skip = False # skip step?
    result3.window_frames.plot = True # make and save plots?
    result3.window_frames.wrad = None # pix; radius of super-Gaussian window mask; if 'None', makes automatic guess
    # Kernel-phase extraction step
    result3.extract_kerphase.skip = False # skip step?
    result3.extract_kerphase.plot = True # make and save plots?
    result3.extract_kerphase.bmax = None # m; maximum baseline length for kernel-phase extraction; if 'None', uses entire pupil model
    # Empirical uncertainties step
    result3.empirical_uncertainties.skip = False # skip step?
    result3.empirical_uncertainties.plot = True # make and save plots?
    result3.empirical_uncertainties.get_emp_err = True # estimate uncertainties empirically from standard deviation over individual frames?
    # Run pipeline
    result3.run(file.replace('uncal', 'calints'))
# Out:
# --> Running fix bad pixels step...
# Found 123365 bad pixels (8.03%)
# Done
# --> Running extract kerphase step...
# Rotating pupil model by -0.57 deg (counter-clockwise)
# Attempting to load file pupil_model.txt
# 230 distinct baselines were identified
# first 10 singular values for this array:
# [14.89703 11.54589 10.39097  8.80026  7.44934  6.31752  6.24093  5.66995
#   5.45849  5.11   ]
# <xara.kpi.KPI object at 0x161e30490> KPI data structure
# ----------------------------------------
# ->  64 sub-apertures
# -> 230 distinct baselines
# -> 167 Ker-phases ( 72.6 % target phase)
# ->  63 Eig-phases (100.0 % wavefront phase)
# ----------------------------------------
#
# KPI data successfully loaded
# File provided is not a fits file
# No KPO data included
#
# First time for m2pix = 5.29:
# LDFT1: Computing new Fourier matrix...
# Done!
# Image shift = (5.03, 0.05)
# Image shift = (5.04, -0.22)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.04, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.25, 0.12)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.02, 0.07)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.07)
# Image shift = (5.02, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.05, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.11, 0.29)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.02, 0.05)
# Image shift = (5.05, -0.23)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.05, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, -0.02)
# Image shift = (5.01, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.01, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.01, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, -0.02)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.00, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.01, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.00, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.01, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.07)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.07)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.05)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.05, 0.14)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.05)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.02, 0.06)
# Image shift = (5.03, 0.05)
# Image shift = (5.02, 0.06)
# Done
# <xara.kpo.KPO object at 0x161e32b00> deleted
# <xara.kpi.KPI object at 0x161e30490> deleted
# --> Running empirical uncertainties step...
# Done
# --> Running fix bad pixels step...
# Found 122737 bad pixels (7.99%)
# Done
# --> Running extract kerphase step...
# Rotating pupil model by -0.57 deg (counter-clockwise)
# Attempting to load file pupil_model.txt
# 230 distinct baselines were identified
# first 10 singular values for this array:
# [14.89703 11.54589 10.39097  8.80026  7.44934  6.31752  6.24093  5.66995
#   5.45849  5.11   ]
# <xara.kpi.KPI object at 0x15f4df700> KPI data structure
# ----------------------------------------
# ->  64 sub-apertures
# -> 230 distinct baselines
# -> 167 Ker-phases ( 72.6 % target phase)
# ->  63 Eig-phases (100.0 % wavefront phase)
# ----------------------------------------
#
# KPI data successfully loaded
# File provided is not a fits file
# No KPO data included
# First time for m2pix = 5.29:
# LDFT1: Computing new Fourier matrix...
# Done!
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.48, 4.52)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.52)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.54)
# Image shift = (9.48, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.47, 4.52)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.52)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.52)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.54)
# Image shift = (9.54, 4.54)
# Image shift = (9.54, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.54)
# Image shift = (9.49, 4.52)
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.48, 4.52)
# Image shift = (9.49, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.48, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.48, 4.52)
# Image shift = (9.48, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.47, 4.52)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.48, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.55)
# Image shift = (9.54, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.68, 4.88)
# Image shift = (9.49, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.54, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.54, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.48, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.48, 4.52)
# Image shift = (9.48, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.48, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.54)
# Image shift = (9.55, 4.53)
# Image shift = (9.48, 4.53)
# Image shift = (9.55, 4.53)
# Image shift = (9.42, 4.57)
# Image shift = (9.54, 4.52)
# Image shift = (9.49, 4.53)
# Image shift = (9.55, 4.54)
# Image shift = (9.54, 4.55)
# Image shift = (9.49, 4.53)
# Image shift = (9.54, 4.54)
# Image shift = (9.54, 4.53)
# Image shift = (9.49, 4.53)
# Done
# <xara.kpo.KPO object at 0x15f4de590> deleted
# <xara.kpi.KPI object at 0x15f4df700> deleted
# --> Running empirical uncertainties step...
# Done
# --> Running fix bad pixels step...
# Found 123343 bad pixels (8.03%)
# Done
# --> Running extract kerphase step...
# Rotating pupil model by -0.57 deg (counter-clockwise)
# Attempting to load file pupil_model.txt
# 230 distinct baselines were identified
# first 10 singular values for this array:
# [14.89703 11.54589 10.39097  8.80026  7.44934  6.31752  6.24093  5.66995
#   5.45849  5.11   ]
# <xara.kpi.KPI object at 0x15f2eedd0> KPI data structure
# ----------------------------------------
# ->  64 sub-apertures
# -> 230 distinct baselines
# -> 167 Ker-phases ( 72.6 % target phase)
# ->  63 Eig-phases (100.0 % wavefront phase)
# ----------------------------------------
#
# KPI data successfully loaded
# File provided is not a fits file
# No KPO data included
#
# First time for m2pix = 5.29:
# LDFT1: Computing new Fourier matrix...
# Done!
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.03)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.87, -0.02)
# Image shift = (4.90, 0.08)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.03)
# Image shift = (4.89, -0.03)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.03)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.03)
# Image shift = (4.88, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.03)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.03)
# Image shift = (4.88, -0.01)
# Image shift = (4.96, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.01)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.87, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.88, -0.02)
# Image shift = (4.96, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.01)
# Image shift = (4.96, -0.01)
# Image shift = (4.81, 0.05)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.90, -0.02)
# Image shift = (4.89, -0.02)
# Image shift = (4.89, -0.01)
# Image shift = (4.90, -0.03)
# Image shift = (4.89, -0.02)
# Image shift = (4.88, -0.01)
# Done
# <xara.kpo.KPO object at 0x15f2ed840> deleted
# <xara.kpi.KPI object at 0x15f2eedd0> deleted
# --> Running empirical uncertainties step...
# Done
# --> Running fix bad pixels step...
# Found 122803 bad pixels (7.99%)
# Done
# --> Running extract kerphase step...
# Rotating pupil model by -0.57 deg (counter-clockwise)
# Attempting to load file pupil_model.txt
# 230 distinct baselines were identified
# first 10 singular values for this array:
# [14.89703 11.54589 10.39097  8.80026  7.44934  6.31752  6.24093  5.66995
#   5.45849  5.11   ]
# <xara.kpi.KPI object at 0x15f50f280> KPI data structure
# ----------------------------------------
# ->  64 sub-apertures
# -> 230 distinct baselines
# -> 167 Ker-phases ( 72.6 % target phase)
# ->  63 Eig-phases (100.0 % wavefront phase)
# ----------------------------------------
#
# KPI data successfully loaded
# File provided is not a fits file
# No KPO data included
#
# First time for m2pix = 5.29:
# LDFT1: Computing new Fourier matrix...
# Done!
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.34, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.45)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.37, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.45)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.30, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.47)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.34, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.30, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.34, 4.45)
# Image shift = (9.27, 4.47)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.31, 4.47)
# Image shift = (9.36, 4.45)
# Image shift = (9.35, 4.47)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.34, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.47)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.45)
# Image shift = (9.36, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.47)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.47)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.47)
# Image shift = (9.36, 4.47)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.47)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.30, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.47)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.47)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.47)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.45)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.47, 4.92)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.35, 4.46)
# Image shift = (9.44, 4.44)
# Image shift = (9.36, 4.46)
# Image shift = (9.36, 4.46)
# Done
# <xara.kpo.KPO object at 0x15f50c9a0> deleted
# <xara.kpi.KPI object at 0x15f50f280> deleted
# --> Running empirical uncertainties step...
# Done
# --> Running fix bad pixels step...
# Found 123400 bad pixels (8.03%)
# Done
# --> Running extract kerphase step...
# Rotating pupil model by -0.57 deg (counter-clockwise)
# Attempting to load file pupil_model.txt
# 230 distinct baselines were identified
# first 10 singular values for this array:
# [14.89703 11.54589 10.39097  8.80026  7.44934  6.31752  6.24093  5.66995
#   5.45849  5.11   ]
# <xara.kpi.KPI object at 0x15f4dcac0> KPI data structure
# ----------------------------------------
# ->  64 sub-apertures
# -> 230 distinct baselines
# -> 167 Ker-phases ( 72.6 % target phase)
# ->  63 Eig-phases (100.0 % wavefront phase)
# ----------------------------------------
#
# KPI data successfully loaded
# File provided is not a fits file
# No KPO data included
#
# First time for m2pix = 5.29:
# LDFT1: Computing new Fourier matrix...
# Done!
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.01, 0.14)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.00, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (4.86, 0.11)
# Image shift = (4.85, 0.11)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.00)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.01, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.01, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.01, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.05, 0.16)
# Image shift = (5.02, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.04, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.01, 0.15)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.25, 0.13)
# Image shift = (5.01, 0.15)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.04, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.01, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.03, 0.09)
# Image shift = (5.02, 0.09)
# Image shift = (5.03, 0.08)
# Image shift = (5.03, 0.08)
# Done
# <xara.kpo.KPO object at 0x15f4dcfd0> deleted
# <xara.kpi.KPI object at 0x15f4dcac0> deleted
# --> Running empirical uncertainties step...
# Done
# --> Running fix bad pixels step...
# Found 122751 bad pixels (7.99%)
# Done
# --> Running extract kerphase step...
# Rotating pupil model by -0.57 deg (counter-clockwise)
# Attempting to load file pupil_model.txt
# 230 distinct baselines were identified
# first 10 singular values for this array:
# [14.89703 11.54589 10.39097  8.80026  7.44934  6.31752  6.24093  5.66995
#   5.45849  5.11   ]
# <xara.kpi.KPI object at 0x15f358a90> KPI data structure
# ----------------------------------------
# ->  64 sub-apertures
# -> 230 distinct baselines
# -> 167 Ker-phases ( 72.6 % target phase)
# ->  63 Eig-phases (100.0 % wavefront phase)
# ----------------------------------------
#
# KPI data successfully loaded
# File provided is not a fits file
# No KPO data included
#
# First time for m2pix = 5.29:
# LDFT1: Computing new Fourier matrix...
# Done!
# Image shift = (9.54, 4.56)
# Image shift = (9.61, 4.55)
# Image shift = (9.49, 4.59)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.55)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.58)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.58)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.58)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.53, 4.33)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.55)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.64)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.58)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.58)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.53, 4.34)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.58)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.58)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.49, 4.81)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.58, 4.97)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.58)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.58)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.54, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.57)
# Image shift = (9.55, 4.56)
# Done
# <xara.kpo.KPO object at 0x15f358610> deleted
# <xara.kpi.KPI object at 0x15f358a90> deleted
# --> Running empirical uncertainties step...
# Done
# --> Running fix bad pixels step...
# Found 123247 bad pixels (8.02%)
# Done
# --> Running extract kerphase step...
# Rotating pupil model by -0.57 deg (counter-clockwise)
# Attempting to load file pupil_model.txt
# 230 distinct baselines were identified
# first 10 singular values for this array:
# [14.89703 11.54589 10.39097  8.80026  7.44934  6.31752  6.24093  5.66995
#   5.45849  5.11   ]
# <xara.kpi.KPI object at 0x15efdb010> KPI data structure
# ----------------------------------------
# ->  64 sub-apertures
# -> 230 distinct baselines
# -> 167 Ker-phases ( 72.6 % target phase)
# ->  63 Eig-phases (100.0 % wavefront phase)
# ----------------------------------------
#
# KPI data successfully loaded
# File provided is not a fits file
# No KPO data included
#
# First time for m2pix = 5.29:
# LDFT1: Computing new Fourier matrix...
# Done!
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.91, 0.04)
# Image shift = (4.88, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.05)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.90, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.87, -0.29)
# Image shift = (4.89, -0.07)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.90, 0.05)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.90, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.05)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.07)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.90, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.85, -0.12)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.05)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.90, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.84, -0.11)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.90, -0.07)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.91, -0.00)
# Image shift = (4.89, -0.06)
# Image shift = (4.90, -0.07)
# Image shift = (4.88, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.07)
# Image shift = (4.97, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.90, 0.05)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.90, -0.06)
# Image shift = (4.88, -0.07)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.78, -0.21)
# Image shift = (4.89, -0.06)
# Image shift = (4.90, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.90, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.88, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.07)
# Image shift = (4.89, -0.06)
# Image shift = (4.89, -0.06)
# Done
# <xara.kpo.KPO object at 0x15efda320> deleted
# <xara.kpi.KPI object at 0x15efdb010> deleted
# --> Running empirical uncertainties step...
# Done
# --> Running fix bad pixels step...
# Found 122908 bad pixels (8.00%)
# Done
# --> Running extract kerphase step...
# Rotating pupil model by -0.57 deg (counter-clockwise)
# Attempting to load file pupil_model.txt
# 230 distinct baselines were identified
# first 10 singular values for this array:
# [14.89703 11.54589 10.39097  8.80026  7.44934  6.31752  6.24093  5.66995
#   5.45849  5.11   ]
# <xara.kpi.KPI object at 0x15f8dd330> KPI data structure
# ----------------------------------------
# ->  64 sub-apertures
# -> 230 distinct baselines
# -> 167 Ker-phases ( 72.6 % target phase)
# ->  63 Eig-phases (100.0 % wavefront phase)
# ----------------------------------------
#
# KPI data successfully loaded
# File provided is not a fits file
# No KPO data included
#
# First time for m2pix = 5.29:
# LDFT1: Computing new Fourier matrix...
# Done!
# Image shift = (9.35, 4.42)
# Image shift = (9.18, 4.21)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.34, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.34, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.34, 4.47)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.34, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.34, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.27, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.41, 4.04)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.47, 4.90)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.37, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.43, 4.02)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.32, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.36, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.34, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.35, 4.41)
# Image shift = (9.34, 4.41)
# Image shift = (9.35, 4.42)
# Image shift = (9.35, 4.42)
# Image shift = (9.36, 4.42)
# Image shift = (9.34, 4.42)
# Image shift = (9.35, 4.42)
# Done
# <xara.kpo.KPO object at 0x15f8dde40> deleted
# <xara.kpi.KPI object at 0x15f8dd330> deleted
# --> Running empirical uncertainties step...
# Done

# %% [markdown]
# ## Step 3: determine contrast limits with fouriever
#
# Fouriever can directly read the KPFITS files from the KPI stage 3 pipeline. The raw 1-sigma noise floor can be computed with the lincmap function in uvfit.

# %%
# Get the KPFITS files of J062802.01-663738.0
fitsfiles = [f.replace('uncal', 'calints_emp_kpfits') for f in files[:2]]

# Load the KPFITS files into fouriever
data = uvfit.data(idir='',
                  fitsfiles=fitsfiles)

# Compute 1-sigma noise floor
fit = data.lincmap(cov=False, # account for data covariance in fit?
                   sep_range=(100., 1000.), # mas; separation range of grid
                   step_size=10., # mas; step size of grid
                   smear=None, # use bandwidth smearing?
                   ofile='raw', # output file name
                   save_as_fits=True) # save output as FITS file?
# Out:
# Opened NIRISS data
#    1 observations
#    230 Fourier phases
#    167 kernel phases
#    1 wavelengths
# Opened NIRISS data
#    1 observations
#    230 Fourier phases
#    167 kernel phases
#    1 wavelengths
# Selected instrument = NIRISS
#    Use self.set_inst(inst) to change the selected instrument
# Selected observables = ['kp']
#    Use self.set_observables(observables) to change the selected observables
# Data properties
#    Smallest spatial scale = 92.5 mas
#    Largest spatial scale = 924.9 mas
#    Using data covariance = False
# Computing grid
#    Min. sep. = 100.0 mas
#    Max. sep. = 1000.0 mas
#    31112 non-empty grid cells
# Computing linear contrast map (DO NOT TRUST UNCERTAINTIES)
#    Cell 40401 of 40401
#    Best fit companion flux = 2.523e-02 +/- 7.590e-07
#    Best fit companion right ascension = -130.0 mas
#    Best fit companion declination = -270.0 mas
#    Best fit companion separation = 299.7 mas
#    Best fit companion position angle = -154.3 deg
#    Best fit red. chi2 = 4.315 (bin)
#    Significance of companion = 6.6 sigma

# %% [markdown]
# In kernel-phase imaging (and AMI), the kernel-phase of the science target is usually calibrated with the kernel-phase of a point-source reference target. Fouriever can perform a Karhunen-Loeve calibration using the calibrate function in klcal. After calibrating the data, the calibrated 1-sigma noise floor can be computed.

# %%
# Output directory where the calibrated KPFITS files are saved
odir = 'cal/'

# Get the KPFITS files of J062802.01-663738.0
scifiles = [f.replace('uncal', 'calints_emp_kpfits') for f in files[:2]]

# Get the KPFITS files of CPD-66-562, CPD-67-607, and TYC-8906-1660-1
calfiles = [f.replace('uncal', 'calints_emp_kpfits') for f in files[2:]]

# Load the KPFITS files into fouriever
data = klcal.data(scidir='',
                  scifiles=scifiles,
                  caldir='',
                  calfiles=calfiles)

# Perform Karhunen-Loeve calibration
data.calibrate(odir=odir,
               K_klip=1)

# Get the calibrated KPFITS files
fitsfiles = [f for f in os.listdir(odir) if f.endswith('emp_kpfits_klcal.fits')]

# Load the KPFITS files into fouriever
data = uvfit.data(idir=odir,
                  fitsfiles=fitsfiles)

# Compute 1-sigma noise floor
fit = data.lincmap(cov=False, # account for data covariance in fit?
                   sep_range=(100., 1000.), # mas; separation range of grid
                   step_size=10., # mas; step size of grid
                   smear=None, # use bandwidth smearing?
                   ofile='cal', # output file name
                   save_as_fits=True) # save output as FITS file?
# Out:
# Selected instrument = NIRISS
#    Use self.set_inst(inst) to change the selected instrument
# Selected observables = ['kp']
#    Use self.set_observables(observables) to change the selected observables
# Computing Karhunen-Loeve decomposition
#    K_klip = 1
#    kp: 6 data sets
#    kp: projection matrix shape = (166, 167)
# Computing Karhunen-Loeve projection
#    File 2 of 2: kernel phase FITS file
# Opened NIRISS data
#    1 observations
#    230 Fourier phases
#    166 kernel phases
#    1 wavelengths
# Opened NIRISS data
#    1 observations
#    230 Fourier phases
#    166 kernel phases
#    1 wavelengths
# Selected instrument = NIRISS
#    Use self.set_inst(inst) to change the selected instrument
# Selected observables = ['kp']
#    Use self.set_observables(observables) to change the selected observables
# Data properties
#    Smallest spatial scale = 92.5 mas
#    Largest spatial scale = 924.9 mas
#    Using data covariance = False
# Computing grid
#    Min. sep. = 100.0 mas
#    Max. sep. = 1000.0 mas
#    31112 non-empty grid cells
# Computing linear contrast map (DO NOT TRUST UNCERTAINTIES)
#    Cell 19046 of 40401
